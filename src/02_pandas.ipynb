# %% [markdown]
# ## 2 Pandas

# %%
#!pip install pandas

# %%
#!conda list pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "Name": ["Suraphop","Linda","John"],
        "Age" : [22,24,53],
        "Sex" : ["male","female","male"]
    }
)

print(df)
print(type(df))
# Out:
#        Name  Age     Sex
# 0  Suraphop   22    male
# 1     Linda   24  female
# 2      John   53    male
# <class 'pandas.core.frame.DataFrame'>

# %%
datas = [["Mark",55,"Italy",4.5,"Europe"],
         ["john",33,"USA",6.9,"America"],
         ["tim",41,"USA",3.9,"America"]]
columns = ["name","age","country","score","continent"]

df = pd.DataFrame(data=datas,columns=columns)
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %% [markdown]
# ## 2.2 Input

# %% [markdown]
# 1.2.1 csv and excel

# %%
df = pd.read_csv(r"C:\Users\nmb_m\OneDrive\Desktop\python_office_2025_02_13\src\data\production_data.csv")
df
# Out:
#      production_date    ng_topic  amount
# 0           1/1/2019        blur       1
# 1           1/1/2019  incomplete       1
# 2           1/1/2019  incomplete       1
# 3           1/1/2019        blur       1
# 4           1/1/2019  incomplete       1
# ...              ...         ...     ...
# 9488       1/31/2019  short mold       1
# 9489       1/31/2019   no solder       1
# 9490       1/31/2019  incomplete       1
# 9491       1/31/2019   no solder       1
# 9492       1/31/2019        burn       1
#
# [9493 rows x 3 columns]

# %%
df = pd.read_csv(r"data\production_data.csv")
df
# Out:
#      production_date    ng_topic  amount
# 0           1/1/2019        blur       1
# 1           1/1/2019  incomplete       1
# 2           1/1/2019  incomplete       1
# 3           1/1/2019        blur       1
# 4           1/1/2019  incomplete       1
# ...              ...         ...     ...
# 9488       1/31/2019  short mold       1
# 9489       1/31/2019   no solder       1
# 9490       1/31/2019  incomplete       1
# 9491       1/31/2019   no solder       1
# 9492       1/31/2019        burn       1
#
# [9493 rows x 3 columns]

# %%
#!pip install openpyxl

# %%
df = pd.read_excel(r"data\ng_data_january.xlsx")
df
# Out:
#      production_date    ng_topic  amount
# 0         2024-01-01        blur       1
# 1         2024-01-01  incomplete       1
# 2         2024-01-01  incomplete       1
# 3         2024-01-01        blur       1
# 4         2024-01-01  incomplete       1
# ...              ...         ...     ...
# 9488      2024-01-31  short mold       1
# 9489      2024-01-31   no solder       1
# 9490      2024-01-31  incomplete       1
# 9491      2024-01-31   no solder       1
# 9492      2024-01-31        burn       1
#
# [9493 rows x 3 columns]

# %% [markdown]
# 1.2.2 local floder

# %%
import os
path = os.getcwd()
path = path + r"/data/sales_data"
#print(path)

xlxs_file_lists = []
file_extension = ".xlsx"

for root,dirs,files in os.walk(path):
    #print(root)
    #print(dirs)
    #print(files)
    for name in files:
        if name.endswith(file_extension):
            file_path = os.path.join(root,name)
            #print(file_path)
            xlxs_file_lists.append(file_path)
xlxs_file_lists
# Out:
# ['c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\April.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\August.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\December.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\February.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\January.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\July.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\June.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\March.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\May.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\November.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\October.xlsx',
#  'c:\\Users\\nmb_m\\OneDrive\\Desktop\\python_office_2025_02_13\\src/data/sales_data\\2024\\September.xlsx']

# %%
df_lists = []
for file in xlxs_file_lists:
    df = pd.read_excel(file)
    #print(df)
    df_lists.append(df)
df_lists
# Out:
# [     transaction_id          store  status transaction_date    plan  \
#  0          7fb801a5        Chicago  ACTIVE       2024-04-01  Silver
#  1          8e8bdb2a  San Francisco  ACTIVE       2024-04-01  Silver
#  2          239db9b6  Washington DC  ACTIVE       2024-04-01  Silver
#  3          7ccb13ab  San Francisco  ACTIVE       2024-04-01    Gold
#  4          c18e82d9        Chicago  ACTIVE       2024-04-01  Bronze
#  ...             ...            ...     ...              ...     ...
#  7428       b3fcd96c         Boston  ACTIVE       2024-04-30  Bronze
#  7429       eec9e52a  San Francisco  ACTIVE       2024-04-30  Silver
#  7430       a9c90deb       New York  ACTIVE       2024-04-30  Bronze
#  7431       d585c5c1       New York  ACTIVE       2024-04-30  Silver
#  7432       f30b34e7  San Francisco  ACTIVE       2024-04-30  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   19.35
#  4              NEW   12.20
#  ...            ...     ...
#  7428           NEW   12.20
#  7429           NEW   14.25
#  7430           NEW   12.20
#  7431           NEW   14.25
#  7432           NEW   14.25
#
#  [7433 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          8d2b0582        Chicago  ACTIVE       2024-08-01  Silver
#  1          61e3773d        Chicago  ACTIVE       2024-08-01    Gold
#  2          52b3f422       New York  ACTIVE       2024-08-01  Bronze
#  3          ae0498f2        Chicago  ACTIVE       2024-08-01  Silver
#  4          7d1f5d57       New York  ACTIVE       2024-08-01  Silver
#  ...             ...            ...     ...              ...     ...
#  8417       47f7aca1  San Francisco  ACTIVE       2024-08-30  Silver
#  8418       2bdcceba         Boston  ACTIVE       2024-08-30  Silver
#  8419       e0aa3c08        Chicago  ACTIVE       2024-08-30  Silver
#  8420       aff115c2  San Francisco  ACTIVE       2024-08-30  Silver
#  8421       0bed8c3d       New York  ACTIVE       2024-08-30  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   19.35
#  2              NEW   12.20
#  3              NEW   14.25
#  4              NEW   14.25
#  ...            ...     ...
#  8417           NEW   14.25
#  8418           NEW   14.25
#  8419           NEW   14.25
#  8420           NEW   14.25
#  8421           NEW   14.25
#
#  [8422 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          0c84fc60       New York  ACTIVE       2024-12-02  Silver
#  1          f369c701  San Francisco  ACTIVE       2024-12-02  Bronze
#  2          1c2558bf        Chicago  ACTIVE       2024-12-02  Silver
#  3          3f98abc7  San Francisco  ACTIVE       2024-12-02  Silver
#  4          1ca71cb6       New York  ACTIVE       2024-12-02  Silver
#  ...             ...            ...     ...              ...     ...
#  7359       07da9a05       New York  ACTIVE       2024-12-31  Silver
#  7360       a776b812  San Francisco  ACTIVE       2024-12-31  Silver
#  7361       16a9246f       New York  ACTIVE       2024-12-31  Silver
#  7362       9ff448be       New York  ACTIVE       2024-12-31    Gold
#  7363       edb00d25       New York  ACTIVE       2024-12-31  Bronze
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   12.20
#  2              NEW   14.25
#  3              NEW   14.25
#  4              NEW   14.25
#  ...            ...     ...
#  7359           NEW   14.25
#  7360           NEW   14.25
#  7361           NEW   14.25
#  7362           NEW   19.35
#  7363           NEW   12.20
#
#  [7364 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          629b9f16       New York  ACTIVE       2024-02-01  Silver
#  1          2f57ac6c      Las Vegas  ACTIVE       2024-02-01  Silver
#  2          45e063e6      Las Vegas  ACTIVE       2024-02-01  Silver
#  3          6ef3a43a       New York  ACTIVE       2024-02-01  Silver
#  4          89f0cec1  San Francisco  ACTIVE       2024-02-01    Gold
#  ...             ...            ...     ...              ...     ...
#  8489       d0782c26        Chicago  ACTIVE       2024-02-28  Silver
#  8490       95c7977e  San Francisco  ACTIVE       2024-02-28  Silver
#  8491       919c37d1       New York  ACTIVE       2024-02-28  Silver
#  8492       b1820c05       New York  ACTIVE       2024-02-28  Bronze
#  8493       efe816e4      Las Vegas  ACTIVE       2024-02-28  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   14.25
#  4              NEW   19.35
#  ...            ...     ...
#  8489           NEW   14.25
#  8490           NEW   14.25
#  8491           NEW   14.25
#  8492           NEW   12.20
#  8493           NEW   14.25
#
#  [8494 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          abfbdd6d        Chicago  ACTIVE       2024-01-01  Silver
#  1          136a9997  San Francisco  ACTIVE       2024-01-01    Gold
#  2          c6688f32  San Francisco  ACTIVE       2024-01-01  Bronze
#  3          6ef349c1        Chicago  ACTIVE       2024-01-01    Gold
#  4          22066f29  San Francisco  ACTIVE       2024-01-01  Silver
#  ...             ...            ...     ...              ...     ...
#  9488       b487a1a6       New York  ACTIVE       2024-01-31  Silver
#  9489       9ab1fb48         Boston  ACTIVE       2024-01-31  Bronze
#  9490       08766c08  San Francisco  ACTIVE       2024-01-31  Silver
#  9491       3e56df84         Boston  ACTIVE       2024-01-31  Bronze
#  9492       2f28e861  Washington DC  ACTIVE       2024-01-31  Bronze
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   19.35
#  2              NEW   12.20
#  3              NEW   19.35
#  4              NEW   14.25
#  ...            ...     ...
#  9488           NEW   14.25
#  9489           NEW   12.20
#  9490           NEW   14.25
#  9491           NEW   12.20
#  9492           NEW   12.20
#
#  [9493 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          b82c1d77       New York  ACTIVE       2024-07-01  Silver
#  1          05c2cb05       New York  ACTIVE       2024-07-01  Silver
#  2          62e4c1ff       New York  ACTIVE       2024-07-01  Silver
#  3          536437fb       New York  ACTIVE       2024-07-01    Gold
#  4          5c126e56  San Francisco  ACTIVE       2024-07-01  Silver
#  ...             ...            ...     ...              ...     ...
#  7159       f05ebfda         Boston  ACTIVE       2024-07-31  Silver
#  7160       dd1e218b  San Francisco  ACTIVE       2024-07-31  Silver
#  7161       6ecfabf4        Chicago  ACTIVE       2024-07-31  Silver
#  7162       063a64a3       New York  ACTIVE       2024-07-31    Gold
#  7163       bd059d1a  San Francisco  ACTIVE       2024-07-31  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   19.35
#  4              NEW   14.25
#  ...            ...     ...
#  7159           NEW   14.25
#  7160           NEW   14.25
#  7161           NEW   14.25
#  7162           NEW   19.35
#  7163           NEW   14.25
#
#  [7164 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          85b9aadf         Boston  ACTIVE       2024-06-03    Gold
#  1          dbc4b91a  San Francisco  ACTIVE       2024-06-03  Silver
#  2          1c425787       New York  ACTIVE       2024-06-03  Silver
#  3          7ba76b0f  San Francisco  ACTIVE       2024-06-03    Gold
#  4          f52e41d9       New York  ACTIVE       2024-06-03  Silver
#  ...             ...            ...     ...              ...     ...
#  8569       9418df9f        Chicago  ACTIVE       2024-06-28  Silver
#  8570       c9ee14da      Las Vegas  ACTIVE       2024-06-28  Silver
#  8571       54026b4a       New York  ACTIVE       2024-06-28  Silver
#  8572       438b3952       New York  ACTIVE       2024-06-28    Gold
#  8573       ac093715       New York  ACTIVE       2024-06-28  Bronze
#
#       contract_type  amount
#  0              NEW   19.35
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   19.35
#  4              NEW   14.25
#  ...            ...     ...
#  8569           NEW   14.25
#  8570           NEW   14.25
#  8571           NEW   14.25
#  8572           NEW   19.35
#  8573           NEW   12.20
#
#  [8574 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          7e189393        Chicago  ACTIVE       2024-03-01  Silver
#  1          ed416609  Washington DC  ACTIVE       2024-03-01  Silver
#  2          c575e712       New York  ACTIVE       2024-03-01  Bronze
#  3          e47af516  San Francisco  ACTIVE       2024-03-01  Silver
#  4          a19ba534       New York  ACTIVE       2024-03-01    Gold
#  ...             ...            ...     ...              ...     ...
#  7559       02050375      Las Vegas  ACTIVE       2024-03-29  Silver
#  7560       18353e1e  San Francisco  ACTIVE       2024-03-29  Bronze
#  7561       8d1f10ff  San Francisco  ACTIVE       2024-03-29  Silver
#  7562       d773cecc  San Francisco  ACTIVE       2024-03-29  Silver
#  7563       b17d5751        Chicago  ACTIVE       2024-03-29  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   12.20
#  3              NEW   14.25
#  4              NEW   19.35
#  ...            ...     ...
#  7559           NEW   14.25
#  7560           NEW   12.20
#  7561           NEW   14.25
#  7562           NEW   14.25
#  7563           NEW   14.25
#
#  [7564 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          449d4aa9       New York  ACTIVE       2024-05-01  Bronze
#  1          6b38f1e5  San Francisco  ACTIVE       2024-05-01  Bronze
#  2          18ec3257  San Francisco  ACTIVE       2024-05-01  Bronze
#  3          4eeb8941  Washington DC  ACTIVE       2024-05-01  Silver
#  4          5e00fae5         Boston  ACTIVE       2024-05-01  Bronze
#  ...             ...            ...     ...              ...     ...
#  7227       3c2155e1        Chicago  ACTIVE       2024-05-31  Silver
#  7228       7ec4f241  Washington DC  ACTIVE       2024-05-31  Silver
#  7229       2da9bdbd        Chicago  ACTIVE       2024-05-31  Silver
#  7230       3a153211  Washington DC  ACTIVE       2024-05-31    Gold
#  7231       3e0f1423  San Francisco  ACTIVE       2024-05-31  Silver
#
#       contract_type  amount
#  0              NEW   12.20
#  1              NEW   12.20
#  2              NEW   12.20
#  3              NEW   14.25
#  4              NEW   12.20
#  ...            ...     ...
#  7227           NEW   14.25
#  7228           NEW   14.25
#  7229           NEW   14.25
#  7230           NEW   19.35
#  7231           NEW   14.25
#
#  [7232 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          ceb84a6b       New York  ACTIVE       2024-11-01    Gold
#  1          940c49b6        Chicago  ACTIVE       2024-11-01  Silver
#  2          07b541d6       New York  ACTIVE       2024-11-01  Bronze
#  3          61d52a79       New York  ACTIVE       2024-11-01    Gold
#  4          3228dd2f        Chicago  ACTIVE       2024-11-01    Gold
#  ...             ...            ...     ...              ...     ...
#  8767       1bc005bd      Las Vegas  ACTIVE       2024-11-29  Bronze
#  8768       cedfdf42  San Francisco  ACTIVE       2024-11-29  Silver
#  8769       668109e8       New York  ACTIVE       2024-11-29  Bronze
#  8770       5135f21a       New York  ACTIVE       2024-11-29  Bronze
#  8771       df2efc44        Chicago  ACTIVE       2024-11-29  Silver
#
#       contract_type  amount
#  0              NEW   19.35
#  1              NEW   14.25
#  2              NEW   12.20
#  3              NEW   19.35
#  4              NEW   19.35
#  ...            ...     ...
#  8767           NEW   12.20
#  8768           NEW   14.25
#  8769           NEW   12.20
#  8770           NEW   12.20
#  8771           NEW   14.25
#
#  [8772 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          a5196775  San Francisco  ACTIVE       2024-10-01  Silver
#  1          24f5b1bd       New York  ACTIVE       2024-10-01  Silver
#  2          7d3a57e3  San Francisco  ACTIVE       2024-10-01  Silver
#  3          1b8c6651         Boston  ACTIVE       2024-10-01  Bronze
#  4          0e42361a         Boston  ACTIVE       2024-10-01  Silver
#  ...             ...            ...     ...              ...     ...
#  5714       0240388f  San Francisco  ACTIVE       2024-10-31  Silver
#  5715       5dd35b12  San Francisco  ACTIVE       2024-10-31    Gold
#  5716       54777a09        Chicago  ACTIVE       2024-10-31  Silver
#  5717       d3fba6d1       New York  ACTIVE       2024-10-31  Silver
#  5718       68defd25        Chicago  ACTIVE       2024-10-31    Gold
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   12.20
#  4              NEW   14.25
#  ...            ...     ...
#  5714           NEW   14.25
#  5715           NEW   19.35
#  5716           NEW   14.25
#  5717           NEW   14.25
#  5718           NEW   19.35
#
#  [5719 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          1625da17       New York  ACTIVE       2024-09-02  Silver
#  1          a60801a8         Boston  ACTIVE       2024-09-02  Silver
#  2          478f5985       New York  ACTIVE       2024-09-02  Silver
#  3          ca84fd4c      Las Vegas  ACTIVE       2024-09-02  Silver
#  4          69fa39a9         Boston  ACTIVE       2024-09-02  Bronze
#  ...             ...            ...     ...              ...     ...
#  7347       53a449b0       New York  ACTIVE       2024-09-30  Silver
#  7348       35b46c26         Boston  ACTIVE       2024-09-30  Silver
#  7349       9e498c85        Chicago  ACTIVE       2024-09-30  Silver
#  7350       5841d16e  San Francisco  ACTIVE       2024-09-30  Silver
#  7351       86937799        Chicago  ACTIVE       2004-12-30    Gold
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   14.25
#  4              NEW   12.20
#  ...            ...     ...
#  7347           NEW   14.25
#  7348           NEW   14.25
#  7349           NEW   14.25
#  7350           NEW   14.25
#  7351           NEW   19.35
#
#  [7352 rows x 7 columns]]

# %%
len(df_lists)
# Out:
# 12

# %%
df_lists[0]
# Out:
#      transaction_id          store  status transaction_date    plan  \
# 0          7fb801a5        Chicago  ACTIVE       2024-04-01  Silver
# 1          8e8bdb2a  San Francisco  ACTIVE       2024-04-01  Silver
# 2          239db9b6  Washington DC  ACTIVE       2024-04-01  Silver
# 3          7ccb13ab  San Francisco  ACTIVE       2024-04-01    Gold
# 4          c18e82d9        Chicago  ACTIVE       2024-04-01  Bronze
# ...             ...            ...     ...              ...     ...
# 7428       b3fcd96c         Boston  ACTIVE       2024-04-30  Bronze
# 7429       eec9e52a  San Francisco  ACTIVE       2024-04-30  Silver
# 7430       a9c90deb       New York  ACTIVE       2024-04-30  Bronze
# 7431       d585c5c1       New York  ACTIVE       2024-04-30  Silver
# 7432       f30b34e7  San Francisco  ACTIVE       2024-04-30  Silver
#
#      contract_type  amount
# 0              NEW   14.25
# 1              NEW   14.25
# 2              NEW   14.25
# 3              NEW   19.35
# 4              NEW   12.20
# ...            ...     ...
# 7428           NEW   12.20
# 7429           NEW   14.25
# 7430           NEW   12.20
# 7431           NEW   14.25
# 7432           NEW   14.25
#
# [7433 rows x 7 columns]

# %%
df_lists[2]
# Out:
#      transaction_id          store  status transaction_date    plan  \
# 0          0c84fc60       New York  ACTIVE       2024-12-02  Silver
# 1          f369c701  San Francisco  ACTIVE       2024-12-02  Bronze
# 2          1c2558bf        Chicago  ACTIVE       2024-12-02  Silver
# 3          3f98abc7  San Francisco  ACTIVE       2024-12-02  Silver
# 4          1ca71cb6       New York  ACTIVE       2024-12-02  Silver
# ...             ...            ...     ...              ...     ...
# 7359       07da9a05       New York  ACTIVE       2024-12-31  Silver
# 7360       a776b812  San Francisco  ACTIVE       2024-12-31  Silver
# 7361       16a9246f       New York  ACTIVE       2024-12-31  Silver
# 7362       9ff448be       New York  ACTIVE       2024-12-31    Gold
# 7363       edb00d25       New York  ACTIVE       2024-12-31  Bronze
#
#      contract_type  amount
# 0              NEW   14.25
# 1              NEW   12.20
# 2              NEW   14.25
# 3              NEW   14.25
# 4              NEW   14.25
# ...            ...     ...
# 7359           NEW   14.25
# 7360           NEW   14.25
# 7361           NEW   14.25
# 7362           NEW   19.35
# 7363           NEW   12.20
#
# [7364 rows x 7 columns]

# %% [markdown]
# 2.2.3 api

# %%
#!pip install requests
import requests

url = "https://covid19.ddc.moph.go.th/api/Cases/today-cases-by-provinces"
res = requests.get(url,headers={"User-Agent" : "Mozilla/5.0"})
data = res.json()
#print(data)

df =pd.DataFrame.from_dict(data)
df
# Out:
#     year  weeknum         province  new_case  total_case  \
# 0   2024        7      หนองบัวลำภู         2          15
# 1   2024        7           พิจิตร         4          47
# 2   2024        7          ขอนแก่น        19         108
# 3   2024        7  ประจวบคีรีขันธ์         1          13
# 4   2024        7         มุกดาหาร         0           3
# ..   ...      ...              ...       ...         ...
# 74  2024        7      สมุทรปราการ         5          64
# 75  2024        7       อำนาจเจริญ         2          10
# 76  2024        7        กำแพงเพชร         1          10
# 77  2024        7             แพร่         4          35
# 78  2024        7         ร้อยเอ็ด         5          72
#
#     new_case_excludeabroad  total_case_excludeabroad  new_death  total_death  \
# 0                        2                        15          0            0
# 1                        4                        47          0            0
# 2                       19                       108          0            0
# 3                        1                        13          0            1
# 4                        0                         3          0            0
# ..                     ...                       ...        ...          ...
# 74                       5                        64          0            3
# 75                       2                        10          0            1
# 76                       1                        10          0            0
# 77                       4                        35          0            0
# 78                       5                        72          0            0
#
#             update_date
# 0   2024-12-23 12:16:13
# 1   2024-12-23 12:16:13
# 2   2024-12-23 12:16:13
# 3   2024-12-23 12:16:13
# 4   2024-12-23 12:16:13
# ..                  ...
# 74  2024-12-23 12:16:13
# 75  2024-12-23 12:16:13
# 76  2024-12-23 12:16:13
# 77  2024-12-23 12:16:13
# 78  2024-12-23 12:16:13
#
# [79 rows x 10 columns]

# %% [markdown]
# 2.2.4 Database

# %%
#!pip install pypyodbc
import pypyodbc

cnxn = pypyodbc.connect("Driver= {SQL Server};"
                        "Server=192.168.1.105;"
                        "Database=test;"
                        "uid=sa;"
                        "pwd=sa$admin")

df = pd.read_sql_query("SELECT * FROM [test].[dbo].[Table_1]",cnxn)
df
# Out:
# C:\Users\nmb_m\AppData\Local\Temp\ipykernel_23884\1253487109.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM [test].[dbo].[Table_1]",cnxn)
#          test
# 0  12
# 1  123
# 2  12
# 3  2
# 4  12
# 5  1
# 6  1
# 7  2
# 8  3
# 9  4

# %% [markdown]
# ## 2.3 Index

# %%
datas = [["Mark",55,"Italy",4.5,"Europe"],
         ["john",33,"USA",6.9,"America"],
         ["tim",41,"USA",3.9,"America"]]
columns = ["name","age","country","score","continent"]

df = pd.DataFrame(data=datas,columns=columns)
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index.name = "user_id"
df
# Out:
#          name  age country  score continent
# user_id
# 0        Mark   55   Italy    4.5    Europe
# 1        john   33     USA    6.9   America
# 2         tim   41     USA    3.9   America

# %%
df.reset_index()
# Out:
#    user_id  name  age country  score continent
# 0        0  Mark   55   Italy    4.5    Europe
# 1        1  john   33     USA    6.9   America
# 2        2   tim   41     USA    3.9   America

# %%
df.set_index("name")
# Out:
#       age country  score continent
# name
# Mark   55   Italy    4.5    Europe
# john   33     USA    6.9   America
# tim    41     USA    3.9   America

# %% [markdown]
# ## 2.4 Sort

# %%
datas = [["Mark",55,"Italy",4.5,"Europe"],
         ["john",33,"USA",6.9,"America"],
         ["tim",41,"USA",3.9,"America"]]
columns = ["name","age","country","score","continent"]

df = pd.DataFrame(data=datas,columns=columns)
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.sort_index()
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.sort_index(ascending=False)
# Out:
#    name  age country  score continent
# 2   tim   41     USA    3.9   America
# 1  john   33     USA    6.9   America
# 0  Mark   55   Italy    4.5    Europe

# %%
df.sort_values(["continent"])
# Out:
#    name  age country  score continent
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America
# 0  Mark   55   Italy    4.5    Europe

# %%
df.sort_values(["continent"],ascending=False)
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.sort_values(["continent","age"])
# Out:
#    name  age country  score continent
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America
# 0  Mark   55   Italy    4.5    Europe

# %% [markdown]
# ## 2.5 Columns

# %%
datas = [["Mark",55,"Italy",4.5,"Europe"],
         ["john",33,"USA",6.9,"America"],
         ["tim",41,"USA",3.9,"America"]]
columns = ["name","age","country","score","continent"]

df = pd.DataFrame(data=datas,columns=columns)
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.columns
# Out:
# Index(['name', 'age', 'country', 'score', 'continent'], dtype='object')

# %%
df.rename(columns={"name" : "first name","age":"AGE"})
# Out:
#   first name  AGE country  score continent
# 0       Mark   55   Italy    4.5    Europe
# 1       john   33     USA    6.9   America
# 2        tim   41     USA    3.9   America

# %%
print(df)
df.rename(columns={"name" : "first name","age":"AGE"},inplace=True)
print(df)
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America
#   first name  AGE country  score continent
# 0       Mark   55   Italy    4.5    Europe
# 1       john   33     USA    6.9   America
# 2        tim   41     USA    3.9   America

# %% [markdown]
# 1.5.2 drop

# %%
datas = [["Mark",55,"Italy",4.5,"Europe"],
         ["john",33,"USA",6.9,"America"],
         ["tim",41,"USA",3.9,"America"]]
columns = ["name","age","country","score","continent"]

df = pd.DataFrame(data=datas,columns=columns)
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.drop(columns=["score","continent"],inplace=True)
df
# Out:
#    name  age country
# 0  Mark   55   Italy
# 1  john   33     USA
# 2   tim   41     USA

# %% [markdown]
# 1.5.3 Transpose

# %%
datas = [["Mark",55,"Italy",4.5,"Europe"],
         ["john",33,"USA",6.9,"America"],
         ["tim",41,"USA",3.9,"America"]]
columns = ["name","age","country","score","continent"]

df = pd.DataFrame(data=datas,columns=columns)
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.T
# Out:
#                 0        1        2
# name         Mark     john      tim
# age            55       33       41
# country     Italy      USA      USA
# score         4.5      6.9      3.9
# continent  Europe  America  America

# %% [markdown]
# ## 4.6 Data Manipulation

# %% [markdown]
# 1.6.1 Selecting

# %%
datas = [["Mark",55,"Italy",4.5,"Europe"],
         ["john",33,"USA",6.9,"America"],
         ["tim",41,"USA",3.9,"America"]]
columns = ["name","age","country","score","continent"]

df = pd.DataFrame(data=datas,columns=columns)
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.loc[0,"name"]
# Out:
# 'Mark'

# %%
df.loc[0,"age"]
# Out:
# np.int64(55)

# %%
df.loc[:1,"age"]
# Out:
# 0    55
# 1    33
# Name: age, dtype: int64

# %%
df.loc[[0,1],"age"]
# Out:
# 0    55
# 1    33
# Name: age, dtype: int64

# %%
df.loc[:2,["name","country"]]
# Out:
#    name country
# 0  Mark   Italy
# 1  john     USA
# 2   tim     USA

# %%
df.iloc[0,0]
# Out:
# 'Mark'

# %%
df.iloc[0,2]
# Out:
# 'Italy'

# %%
df[df["age"] > 40]
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 2   tim   41     USA    3.9   America

# %%
df[(df["age"] > 40)  & (df["country"] == "USA")] # and
# Out:
#   name  age country  score continent
# 2  tim   41     USA    3.9   America

# %%
df[(df["age"] > 40) | (df["country"] == "USA")] #or
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %% [markdown]
# example1 :
# - score >4 and continent is Europe or America
#
# example2 :
# - age >40 and continent is Europe or America

# %%
df[(df["score"] > 4) & ((df["continent"] == "Europe") | (df["continent"] == "America")) ]
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America

# %%
df[(df["age"] > 40) & ((df["continent"] == "Europe") | (df["continent"] == "America")) ]
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 2   tim   41     USA    3.9   America

# %%
df[df["country"].isin(["Italy"])]
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe

# %% [markdown]
# 1.6.2 Update

# %%
datas = [["Mark",55,"Italy",4.5,"Europe"],
         ["john",33,"USA",6.9,"America"],
         ["tim",41,"USA",3.9,"America"]]
columns = ["name","age","country","score","continent"]

df = pd.DataFrame(data=datas,columns=columns)
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  john   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df.loc[1,"name"] = "JOHN"
df
# Out:
#    name  age country  score continent
# 0  Mark   55   Italy    4.5    Europe
# 1  JOHN   33     USA    6.9   America
# 2   tim   41     USA    3.9   America

# %%
df["score"][df["age"] > 45] = 1.1

df
# Out:
# C:\Users\nmb_m\AppData\Local\Temp\ipykernel_23884\3305068722.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["score"][df["age"] > 45] = 1.1
# C:\Users\nmb_m\AppData\Local\Temp\ipykernel_23884\3305068722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["score"][df["age"] > 45] = 1.1
#    name  age country  score continent
# 0  Mark   55   Italy    1.1    Europe
# 1  JOHN   33     USA    6.9   America
# 2   tim   41     USA    3.9   America
