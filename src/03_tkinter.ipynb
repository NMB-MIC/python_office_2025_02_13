# %% [markdown]
# 5 Tkinter

# %% [markdown]
# 5.1 example1 convert temperature

# %%
#example convert temperature scale 
import tkinter as tk
from tkinter import ttk
from tkinter.messagebox import showerror

# root window
root = tk.Tk()
root.title('Temperature Converter')
root.geometry('300x70')
root.resizable(False, False)

def fahrenheit_to_celsius(f):
    """ Convert fahrenheit to celsius
    """
    return (f - 32) * 5/9

# frame
frame = ttk.Frame(root)

# field options
options = {'padx': 5, 'pady': 5}

# temperature label
temperature_label = ttk.Label(frame, text='Fahrenheit')
temperature_label.grid(column=0, row=0, sticky='W', **options)

# temperature entry
temperature = tk.StringVar()
temperature_entry = ttk.Entry(frame, textvariable=temperature)
temperature_entry.grid(column=1, row=0, **options)
temperature_entry.focus()

# convert button
def convert_button_clicked():
    """  Handle convert button click event 
    """
    try:
        f = float(temperature.get())
        c = fahrenheit_to_celsius(f)
        result = f'{f} Fahrenheit = {c:.2f} Celsius'
        result_label.config(text=result)
    except ValueError as error:
        showerror(title='Error', message=error)

convert_button = ttk.Button(frame, text='Convert')
convert_button.grid(column=2, row=0, sticky='W', **options)
convert_button.configure(command=convert_button_clicked)

# result label
result_label = ttk.Label(frame)
result_label.grid(row=1, columnspan=3, **options)

# add padding to the frame and show it
frame.grid(padx=10, pady=10)

# start the app
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from convert_temperature import convert_to_celsius

root = tk.Tk()
root.title("Temperature Convert")
root.geometry("430x70")
root.resizable(False,False)

options = {'padx':5,'pady':5}

frame = ttk.Frame(root)
temperature_label = ttk.Label(frame,text="degrees")
temperature_label.grid(column=0,row=0,**options)

temperature = tk.StringVar()
temperature_entry = ttk.Entry(frame,textvariable=temperature)
temperature_entry.grid(column=1,row=0,**options)
temperature_entry.focus()

source_dropdown_clicked = tk.StringVar()
source_dropdown_clicked.set("fahrenhite")
drop_down_list = ["fahrenhite","kelvin"]
source_dropdown = ttk.OptionMenu(frame,source_dropdown_clicked,drop_down_list[0],*drop_down_list)
source_dropdown.grid(column=2,row=0,**options)

def convert_button_clicked():
    """Handle convert button cluck event"""
    degrees = temperature.get()
    source = source_dropdown_clicked.get()
    result = convert_to_celsius(degrees,source)
    result_label.config(text=result)
    
convert_button = ttk.Button(frame,text="Convert")
convert_button.grid(column=3,row=0,**options)
convert_button.configure(command=convert_button_clicked)

result_label = ttk.Label(frame)
result_label.grid(columnspan=4,row=1,**options)

frame.grid(padx=10,pady=10)
root.mainloop()

# %% [markdown]
# 5.2 example2 making daily report

# %%
# Python program to create
# a file explorer in Tkinter
  
# import all components
# from the tkinter library
from tkinter import *
from tkinter import messagebox

# import filedialog module
from tkinter import filedialog

from report_daily_thinker import report_sale_amount

xlsx_file_name = None
# Function for opening the
# file explorer window
def browseFiles():
    global xlsx_file_name

    filename = filedialog.askopenfilename(initialdir = "/",
                                          title = "Select a File",
                                          filetypes = (("excel files",
                                                        "*.xlsx*"),
                                                       ("all files",
                                                        "*.*")))
    xlsx_file_name = filename
    # Change label contents
    label_file_explorer.configure(text="File Opened: "+filename)
      
def making_report():
    global xlsx_file_name
    try:
      report_sale_amount(xlsx_file_name)
      messagebox.showinfo("info", "Making report success")    
    except Exception as e:
      messagebox.showerror("Error!", e)  
                                                                                                  
# Create the root window
window = Tk()
  
# Set window title
window.title('File Explorer')
  
# Set window size
window.geometry("470x150")
window.resizable(False, False)
#Set window background color

  
# Create a File Explorer label
label_file_explorer = Label(window,
                            text = "File Explorer",
                            width = 50, height = 4,
                            fg = "blue")
      
button_explore = Button(window,
                        text = "Browse Files",
                        command = browseFiles)

# field options
options = {'padx': 5, 'pady': 5}

button_report = Button(window,
                     text = "Making report", height= 2, width=50,
                     command = making_report)
  
label_file_explorer.grid(column = 1, row = 1, **options)
  
button_explore.grid(column = 2, row = 1, **options)
  
button_report.grid(column = 1,row = 2, **options)
  
# Let the window wait for any events
window.mainloop()

# %%
#!pip install pyinstaller

# %%
#build tinker to exe (dont run in jupyter,only build in cmd)
#!pyinstaller.exe --noconsole --onefile report_daily_production.py
# Out:
# 388 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 389 INFO: Python: 3.12.4 (conda)
# 434 INFO: Platform: Windows-11-10.0.22631-SP0
# 434 INFO: Python environment: C:\Users\nmb_m\miniconda3\envs\test
# 456 INFO: wrote g:\My Drive\project\training_python_course_for_office\src\report_daily_production.spec
# 511 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\python312.zip',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\DLLs',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\win32',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\setuptools\\_vendor',
#  'g:\\My Drive\\project\\training_python_course_for_office\\src']
# 1088 INFO: checking Analysis
# 1089 INFO: Building Analysis because Analysis-00.toc is non existent
# 1089 INFO: Running Analysis Analysis-00.toc
# 1089 INFO: Target bytecode optimization level: 0
# 1089 INFO: Initializing module dependency graph...
# 1090 INFO: Caching module graph hooks...
# 1109 INFO: Analyzing base_library.zip ...
# 4261 INFO: Processing standard module hook 'hook-encodings.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 6978 INFO: Processing standard module hook 'hook-pickle.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 8464 INFO: Processing standard module hook 'hook-heapq.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 8932 INFO: Caching module dependency graph...
# 9300 INFO: Looking for Python shared library...
# 9308 INFO: Using Python shared library: C:\Users\nmb_m\miniconda3\envs\test\python312.dll
# 9308 INFO: Analyzing g:\My Drive\project\training_python_course_for_office\src\report_daily_production.py
# 9455 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 9504 INFO: Processing standard module hook 'hook-pandas.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 11687 INFO: Processing standard module hook 'hook-platform.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 11943 INFO: Processing standard module hook 'hook-sysconfig.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 12014 INFO: Processing standard module hook 'hook-numpy.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\numpy\\_pyinstaller'
# 12075 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 14167 INFO: Processing standard module hook 'hook-difflib.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 14410 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 14556 INFO: Processing standard module hook 'hook-xml.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 15762 INFO: Processing standard module hook 'hook-psutil.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 17578 INFO: Processing standard module hook 'hook-pytz.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 17964 INFO: Processing standard module hook 'hook-pkg_resources.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 17964 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 24511 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 24541 INFO: Processing standard module hook 'hook-packaging.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 24634 INFO: Processing pre-safe-import-module hook 'hook-jaraco.text.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 24634 INFO: Setuptools: 'jaraco.text' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.text'!
# 24646 INFO: Processing standard module hook 'hook-setuptools.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 24725 INFO: Processing pre-safe-import-module hook 'hook-distutils.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25290 INFO: Processing pre-safe-import-module hook 'hook-more_itertools.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25291 INFO: Setuptools: 'more_itertools' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.more_itertools'!
# 25416 INFO: Processing pre-safe-import-module hook 'hook-importlib_metadata.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25416 INFO: Setuptools: 'importlib_metadata' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.importlib_metadata'!
# 25451 INFO: Processing pre-safe-import-module hook 'hook-zipp.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25451 INFO: Setuptools: 'zipp' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.zipp'!
# 25486 INFO: Processing pre-safe-import-module hook 'hook-importlib_resources.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25487 INFO: Setuptools: 'importlib_resources' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.importlib_resources'!
# 25603 INFO: Processing pre-safe-import-module hook 'hook-ordered_set.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25604 INFO: Setuptools: 'ordered_set' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.ordered_set'!
# 25624 INFO: Processing pre-safe-import-module hook 'hook-jaraco.functools.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25625 INFO: Setuptools: 'jaraco.functools' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.functools'!
# 25745 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25909 INFO: Processing pre-safe-import-module hook 'hook-tomli.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 25909 INFO: Setuptools: 'tomli' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.tomli'!
# 26509 INFO: Processing pre-safe-import-module hook 'hook-wheel.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26740 INFO: Processing pre-safe-import-module hook 'hook-jaraco.context.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26741 INFO: Setuptools: 'jaraco.context' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco.context'!
# 26809 INFO: Processing pre-safe-import-module hook 'hook-backports.tarfile.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26810 INFO: Setuptools: 'backports.tarfile' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.backports.tarfile'!
# 26915 INFO: Processing standard module hook 'hook-backports.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 26917 INFO: Processing pre-safe-import-module hook 'hook-platformdirs.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26928 INFO: Processing standard module hook 'hook-platformdirs.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 29478 INFO: Processing standard module hook 'hook-pandas.io.formats.style.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 31352 INFO: Processing standard module hook 'hook-IPython.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 34152 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 34521 INFO: Processing standard module hook 'hook-pygments.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 37206 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 38161 INFO: Processing standard module hook 'hook-wcwidth.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 39498 INFO: Processing standard module hook 'hook-jedi.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 40879 INFO: Processing standard module hook 'hook-parso.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 42698 INFO: Processing standard module hook 'hook-sqlite3.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 43783 INFO: Processing standard module hook 'hook-zmq.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 45919 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 47089 INFO: Processing standard module hook 'hook-pandas.plotting.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 47799 INFO: Processing standard module hook 'hook-openpyxl.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 48470 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 50794 INFO: Processing standard module hook 'hook-pandas.io.clipboard.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 51593 INFO: Processing module hooks (post-graph stage)...
# 51635 WARNING: Hidden import "jinja2" not found!
# 54227 INFO: Processing pre-safe-import-module hook 'hook-autocommand.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 54227 INFO: Setuptools: 'autocommand' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.autocommand'!
# 54367 INFO: Processing pre-safe-import-module hook 'hook-typeguard.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 54368 INFO: Setuptools: 'typeguard' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.typeguard'!
# 55248 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks'
# 55248 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 55463 INFO: Performing binary vs. data reclassification (3461 entries)
# 55951 INFO: Looking for ctypes DLLs
# 56062 INFO: Analyzing run-time hooks ...
# 56073 INFO: Including run-time hook 'pyi_rth_inspect.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 56075 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 56079 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 56081 INFO: Including run-time hook 'pyi_rth_traitlets.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\rthooks'
# 56082 INFO: Including run-time hook 'pyi_rth_pkgres.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 56088 INFO: Including run-time hook 'pyi_rth_setuptools.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 56089 INFO: Including run-time hook 'pyi_rth__tkinter.py' from 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 56271 INFO: Looking for dynamic libraries
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 60860 INFO: Extra DLL search directories (AddDllDirectory): ['C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\pandas.libs', 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\numpy.libs', 'C:\\Users\\nmb_m\\miniconda3\\envs\\test\\Lib\\site-packages\\pyzmq.libs']
# 60860 INFO: Extra DLL search directories (PATH): []
# 62651 INFO: Warnings written to g:\My Drive\project\training_python_course_for_office\src\build\report_daily_production\warn-report_daily_production.txt
# 63219 INFO: Graph cross-reference written to g:\My Drive\project\training_python_course_for_office\src\build\report_daily_production\xref-report_daily_production.html
# 63651 INFO: checking PYZ
# 63652 INFO: Building PYZ because PYZ-00.toc is non existent
# 63652 INFO: Building PYZ (ZlibArchive) g:\My Drive\project\training_python_course_for_office\src\build\report_daily_production\PYZ-00.pyz
# 67323 INFO: Building PYZ (ZlibArchive) g:\My Drive\project\training_python_course_for_office\src\build\report_daily_production\PYZ-00.pyz completed successfully.
# 67407 INFO: checking PKG
# 67409 INFO: Building PKG because PKG-00.toc is non existent
# 67409 INFO: Building PKG (CArchive) report_daily_production.pkg
# 67574 INFO: Building PKG (CArchive) report_daily_production.pkg completed successfully.
# 67588 INFO: Bootloader C:\Users\nmb_m\miniconda3\envs\test\Lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\runw.exe
# 67588 INFO: checking EXE
# 67589 INFO: Building EXE because EXE-00.toc is non existent
# 67589 INFO: Building EXE from EXE-00.toc
# 67590 INFO: Copying bootloader EXE to g:\My Drive\project\training_python_course_for_office\src\build\report_daily_production\report_daily_production.exe
# 67703 INFO: Copying icon to EXE
# 67795 INFO: Copying 0 resources to EXE
# 67795 INFO: Embedding manifest in EXE
# 67906 INFO: Appending PKG archive to EXE
# 68037 INFO: Fixing EXE headers
# 68460 INFO: Building EXE from EXE-00.toc completed successfully.
# 68543 INFO: checking COLLECT
# 68547 INFO: Building COLLECT because COLLECT-00.toc is non existent
# 68602 INFO: Building COLLECT COLLECT-00.toc
# 167488 INFO: Building COLLECT COLLECT-00.toc completed successfully.
